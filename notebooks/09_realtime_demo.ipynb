# %% [markdown]
# # Notebook 09: Real-Time Demo
#
# **Planned content:**
# - Streaming simulation: feed ECG in overlapping 2.5-sec windows as they arrive
# - Rolling prediction update with confidence bars per class
# - Latency benchmarking: inference time per window on CPU vs GPU
# - Interactive widget (ipywidgets) to select record and watch predictions evolve
#
# Run notebooks 03–06 before this one.
